# %%
#calculate distance between two geometrical points

import math

x01 = input("Enter the value of x1 : ")
x1 = int(x01)
x02 = input("Enter the value of x2 : ")
x2 = int(x02)

y01 = input("Enter the value of y1 : ")
y1 = int(y01)
y02 = input("Enter the value of y2 : ")
y2 = int(y02)

distance = math.pow((x2-x1),2) + math.pow((y2-y1),2)
print("Distance : " ,math.sqrt(distance))
# Out:
# Enter the value of x1 : 4
# Enter the value of x2 : 2
# Enter the value of y1 : 4
# Enter the value of y2 : 2
# Distance :  2.8284271247461903

# %%
#Write a program that asks user to enter two numbers, a and b; and tells the user whether a is divisible by b or not?

num1 = input('Enter the first number : ')
a = int(num1)
num2 = input('Enter the second number : ')
b = int(num2)
if a%b==0:
  print("A is divisible")
else:
  print("A is not divisible")
# Out:
# Enter the first number : 9
# Enter the second number : 3
# A is divisible

# %%
#A number can be an even or can be odd. It is either positive or negative. 
#Or in all other case it can be nothing, but a zero. Well, what if we combine them all. 
#Write a program that asks user to enter a number. 
#Your program, then, tells that the number entered is one of these: positive even, positive odd, negative even, negative odd or it’s nothing but a zero.

number = input('Enter a number : ')
num = int(number)
if num > 0 and num%2==0:
  print('Number is positive even.')
elif num > 0:
  print('Number is positive odd.')
elif num < 0 and num%2==0:
  print('Number is negative even.')
elif num < 0:
  print('Number is negative odd.')
else:
  print('Number is nothing but a zero')
# Out:
# Enter a number : -2
# Number is negative even.

# %%
day = int(input('Enter the day from (1-7): '))
money = int(input('Enter the money : '))

if day==1:
  if money>=15 and money<=50:
    print('Deal 01')
  elif money>=51 and money<=100:
    print('Deal 01 and Deal 02')
  elif money>=101:
    print('Deal 01, Deal 02, Deal 03 + complementary sweets')
  else:
    print('Sorry! No deal')
elif day==2 or day==3:
  if money>=15 and money<=50:
    print('Deal 01')
  elif money>=51 and money<=100:
    print('Deal 01 and Deal 04')
  elif money>=101:
    print('Deal 01, Deal 04, Deal 05 + complementary shake')
  else:
    print('Sorry! No deal')
elif day==4 or day==5:
  if money>=15 and money<=50:
    print('Deal 01')
  elif money>=51 and money<=100:
    print('Deal 01 and Deal 06')
  elif money>=101:
    print('Deal 01, Deal 06, Deal 07 + complementary Falooda')
  else:
    print('Sorry! No deal')
elif day==6 or day==7:
  if money>=15 and money<=50:
    print('Deal 01 + complementary soup')
  elif money>=150:
    print('Buffet')
  else:
    print('Sorry! No deal')
else:
  print('Thankyou! Have a nice day...')
# Out:
# Enter the day from (1-7): 15
# Enter the money : 2
# Thankyou! Have a nice day...

# %%
import math
radarRange = 100
latitudeOfKarachi = 24.868622
longitiudeOfKarachi = 66.761121

latitudeOfA = 25.026488
latitudeOfB = 23.982498
latitudeOfC = 23.958768

longitudeOfA = 66.524507
longitudeOfB = 66.881661
longitudeOfC = 67.306088

distanceA = (math.pow(latitudeOfKarachi-latitudeOfA,2))+(math.pow(longitiudeOfKarachi-longitudeOfA,2))
distanceOfA = (math.sqrt(distanceA))
distanceB = (math.pow(latitudeOfKarachi-latitudeOfB,2))+(math.pow(longitiudeOfKarachi-longitudeOfB,2))
distanceOfB = (math.sqrt(distanceB))
distanceC = (math.pow(latitudeOfKarachi-latitudeOfC,2))+(math.pow(longitiudeOfKarachi-longitudeOfC,2))
distanceOfC = (math.sqrt(distanceC))

if distanceOfA<= radarRange:
  print('Radar datect the airplane over the location.')
else:
  print('Radar cannot datect the aeroplane') 
  
if distanceOfB <= radarRange:
  print('Radar datect the airplane over the location.')
else:
  print('Radar cannot datect the aeroplane')
  
if distanceOfC <= radarRange:
  print('Radar datect the airplane over the location.')
else:
  print('Radar cannot datect the aeroplane')
# Out:
# Radar datect the airplane over the location.
# Radar datect the airplane over the location.
# Radar datect the airplane over the location.

# %%
num1 = int(input('Enter a number : '))
num2 = int(input('Enter a number : '))
for num in range(num1,num2):
  print('Range is : ',num)
# Out:
# Enter a number : 2
# Enter a number : 7
# Range is :  2
# Range is :  3
# Range is :  4
# Range is :  5
# Range is :  6

# %%
hiddenNumber = 7
first = int(input('Guess the hidden number (Chance #01) :'))
if first == hiddenNumber:
  print('You Win!!')
else:
  print('Game Lost')
second = int(input('Guess the hidden number (Chance #02) :'))
if second == hiddenNumber:
  print('You Win!!')
else:
  print('Game Lost')
third = int(input('Guess the hidden number (Chance #03) :'))
if third == hiddenNumber:
  print('You Win!!')
else:
  print('Game Lost')
# Out:
# Guess the hidden number (Chance #01) :3
# Game Lost
# Guess the hidden number (Chance #02) :4
# Game Lost
# Guess the hidden number (Chance #03) :7
# You Win!!

# %%
x = 3
y = 4
count = 1
x1 = 0
x2 = 0
while True: 
  for x1 in range(x,y):
    print('%d^%d = %d' % (x,count,x1*count))
  if(count==y):
    break
  count = count + 1
# Out:
# 3^1 = 3
# 3^2 = 6
# 3^3 = 9
# 3^4 = 12

# %%
num = float(input("Enter the value of x : "))
count = 1
x = 0
while (count <= num):
  x = x + (1/count)       
  count = count + 1
print('The ratio is :', x)
# Out:
# Enter the value of x : 2
# The ratio is : 1.5

# %% [markdown]
# # Below are the tasks from the university of CANADA of my cousin which I performed.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
'''calculates population of Ecoli cells''' 
#docstring telling system that population of Ecoli cells is being calculated
#ask user to plug in the initial vlaue of Ecoli cells

import math 

def Population_of_Ecoli_cells():
    yo = float(input("Enter the initial population of Ecoli cells: "))
    e = 1
    k = 0.0347
    
    t60 = yo * math.exp(k * 60)
    t120 = yo * math.exp(k * 120)
    t240 = yo * math.exp(k * 240)
    t1440 = yo * math.exp(k * 1440)
    t4320 = yo * math.exp(k * 4320)

    return("time at 60 minutes", t60, "time at 120 minutes", t120, "time at 240 minutes", t240, "time after 1440 minutes", t1440, "time after 4320 minutes", t4320)

Population_of_Ecoli_cells()
# Out:
# Enter the initial population of Ecoli cells: 2
# ('time at 60 minutes',
#  16.04098774348148,
#  'time at 120 minutes',
#  128.65664389326153,
#  'time at 240 minutes',
#  8276.266008938754,
#  'time after 1440 minutes',
#  1.0042842861158005e+22,
#  'time after 4320 minutes',
#  2.532270005771214e+65)

# %% [markdown]
# Question 1: Solutions to the Quadratic Equation
#
# Write a program that computes the real solution(s) to the quadratic equation:
#
# ax2+bx+c=0ax2+bx+c=0
# Your program should do the following:
#
# Ask the user to enter the values of a, b and c (these should be of type float).
# Check whether there are real solutions.
# If there are real solution(s), compute and print them.
# If there are not, inform the user.
# Use at least one function from the module numpy.
# Print the solution(s), if they exist.

# %%
import numpy

def Quadratic_Equation():
    """ This function calculates solution to quadratic equation. """

    a = float(input("a ")) #input the value of a
    b = float(input("b ")) #input the value of b
    c = float(input("c ")) #input the value of c

    value = numpy.sqrt(b**2 - 4*a*c)

    if value >= 0:
      print("Solution to quadratic equation is:")

      first = -b + value 
      positive = first / 2*a

      second = -b - value 
      negative = second / 2*a  

      print('The positive is : ', positive, ' and the negative is :', negative) 

    else:
      print("Solution doesn\'t exist.")

Quadratic_Equation()
# Out:
# a 2
# b 5
# c -3
# Solution to quadratic equation is:
# The positive is :  2.0  and the negative is : -12.0

# %%
import numpy

weather_data = numpy.loadtxt(fname='/content/drive/My Drive/toronto_weather_sept_2018.csv', delimiter=',')
print(weather_data)
weather_data.shape
# Out:
# [[  0.   15.   95.    3. ]
#  [  1.   14.5  95.    3. ]
#  [  2.   14.1  96.    4. ]
#  ...
#  [597.   20.7  95.   13. ]
#  [598.   20.7  96.   22. ]
#  [599.   20.4  97.   17. ]]
# (600, 4)

# %%
print("The mean temperature :", weather_data.mean(axis=0)[1])
print("The min temperature :", weather_data.min(axis=0)[2])
print("The max temperature :", weather_data.max(axis=0)[3])
# Out:
# The mean temperature : 18.967999999999996
# The min temperature : 40.0
# The max temperature : 40.0

# %%
import numpy as np
import matplotlib.pyplot as mpp

data = np.loadtxt(fname='/content/drive/My Drive/inflammation.csv', delimiter=',')

# By default Plot() function will draw a line chart.
mpp.plot(data)
mpp.show()

# %%
import numpy
import matplotlib.pyplot

data = numpy.loadtxt(fname='/content/drive/My Drive/toronto_weather_sept_2018.csv', delimiter=',', usecols=[1])

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))
axes1 = fig.add_subplot(1, 3, 1)
axes1.set_ylabel('Temperature')
axes1.plot(data)

fig.tight_layout()
matplotlib.pyplot.show()

# %%
import numpy
import matplotlib.pyplot

data = numpy.loadtxt(fname='/content/drive/My Drive/toronto_weather_sept_2018.csv', delimiter=',', usecols=[2])

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes1 = fig.add_subplot(1, 3, 1)

axes1.set_ylabel('Temperature')
axes1.plot(data)

fig.tight_layout()
matplotlib.pyplot.show()

# %%
import numpy
data = numpy.loadtxt(fname='/content/drive/My Drive/polynomial_coefficients.csv', delimiter=',')
x = float(input("Enter the value of x : "))
count = 8
sum = 0

for i in data:
  value = i * x ** count
  count = count - 1
  sum = sum + value
  
print("The ans is : ",sum)
# Out:
# Enter the value of x : 2
# The ans is :  1678.8260000000005

# %%
import numpy
data = numpy.loadtxt(fname='/content/drive/My Drive/arthritis_inflammation.csv', delimiter=',')
x = data.mean(axis=0)
print("The avg inflammation for each patient is: ")
print(x)
max = 0

for i in x:
  if i > max:
    max = i
  else:
    continue

print("The max inflammation is :", max)
# Out:
# The avg inflammation for each patient is:
# [0.         0.         0.58333333 1.53333333 0.4        2.4
#  3.23333333 3.6        2.95       5.58333333 3.28333333 7.78333333
#  4.13333333 3.01666667 9.01666667 7.8        4.21666667 9.75
#  8.53333333 7.81666667 6.76666667 7.9        4.46666667 8.51666667
#  8.35       4.31666667 7.55       4.01666667 7.6        3.18333333
#  4.23333333 4.21666667 2.36666667 3.11666667 2.81666667 1.26666667
#  1.4        0.46666667 0.         0.        ]
# The max inflammation is : 9.75

# %%
import glob
import numpy
import matplotlib.pyplot

path = glob.glob('/content/drive/My Drive/data/*.csv')
['temp-01.csv', 'temp-02.csv', 'temp-03.csv', 'temp-04.csv', 'temp-05.csv', 'temp-06.csv']

for files in path:
  data = numpy.loadtxt(fname = files, delimiter=',')

  fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))
  axes = fig.add_subplot(1, 3, 1)  
  axes.set_ylabel('Temperature')
  axes.plot(data)

  fig.tight_layout()
  matplotlib.pyplot.show()

  print("Name of file :", files)
  print("The mean temperature :", data.mean(axis=0))
  print("The man temperature :", data.max(axis=0))
  print("The mix temperature :", data.min(axis=0))
# Out:
# Name of file : /content/drive/My Drive/data/temp-03.csv
# The mean temperature : -0.7010752688172042
# The man temperature : 8.2
# The mix temperature : -8.5
# Name of file : /content/drive/My Drive/data/temp-05.csv
# The mean temperature : 16.869272237196764
# The man temperature : 30.6
# The mix temperature : 4.4
# Name of file : /content/drive/My Drive/data/temp-06.csv
# The mean temperature : 19.298887343532684
# The man temperature : 35.8
# The mix temperature : 10.0
# Name of file : /content/drive/My Drive/data/temp-04.csv
# The mean temperature : 2.813540197461213
# The man temperature : 18.1
# The mix temperature : -7.4
# Name of file : /content/drive/My Drive/data/temp-01.csv
# The mean temperature : -6.061290322580645
# The man temperature : 11.6
# The mix temperature : -25.0
# Name of file : /content/drive/My Drive/data/temp-02.csv
# The mean temperature : -2.1140089418777945
# The man temperature : 15.0
# The mix temperature : -16.8

# %%
import glob
import numpy
import matplotlib.pyplot

path = glob.glob('/content/drive/My Drive/data/*.csv')
['temp-01.csv', 'temp-02.csv', 'temp-03.csv', 'temp-04.csv', 'temp-05.csv', 'temp-06.csv']

for files in path:
  data = numpy.loadtxt(fname = files, delimiter=',')
  print("Name of file :", files)
# Out:
# Name of file : /content/drive/My Drive/data/temp-03.csv
# Name of file : /content/drive/My Drive/data/temp-05.csv
# Name of file : /content/drive/My Drive/data/temp-06.csv
# Name of file : /content/drive/My Drive/data/temp-04.csv
# Name of file : /content/drive/My Drive/data/temp-01.csv
# Name of file : /content/drive/My Drive/data/temp-02.csv
